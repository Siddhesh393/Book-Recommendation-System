# %%
import pandas as pd
import numpy as np
import joblib

# %%
user = pd.read_csv("data/Users.csv", encoding="latin1", engine="python", on_bad_lines="skip")
book = pd.read_csv("data/Books.csv", encoding='latin1')
rating=pd.read_csv("data/Ratings.csv",encoding='latin1')
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_49688\2766897497.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv("data/Books.csv", encoding='latin1')

# %%
user.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
rating_up = rating.merge(book[['ISBN', 'Book-Title']], on='ISBN', how='left')
rating_up
# Out:
#          User-ID         ISBN  Book-Rating  \
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
#                                                 Book-Title
# 0                                     Flesh Tones: A Novel
# 1                                         Rites of Passage
# 2                                             The Notebook
# 3                                           Help!: Level 1
# 4        The Amsterdam Connection : Level 4 (Cambridge ...
# ...                                                    ...
# 1149775  Get Clark Smart : The Ultimate Guide for the S...
# 1149776  Eight Weeks to Optimum Health: A Proven Progra...
# 1149777   The Sherbrooke Bride (Bride Trilogy (Paperback))
# 1149778                                  Fourth Grade Rats
# 1149779                                                NaN
#
# [1149780 rows x 4 columns]

# %%
null_values1 = rating_up['Book-Title'].isnull().sum()
null_values2 = len(rating_up)

# %%
print(f'These are the number of non null records : {null_values2 - null_values1}')
# Out:
# These are the number of non null records : 1031136

# %%
rating_up.dropna(subset=['Book-Title'],inplace=True)
rating_up.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
#
#                                           Book-Title
# 0                               Flesh Tones: A Novel
# 1                                   Rites of Passage
# 2                                       The Notebook
# 3                                     Help!: Level 1
# 4  The Amsterdam Connection : Level 4 (Cambridge ...

# %%
len(rating_up)
# Out:
# 1031136

# %%
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
rating_up['user_index'] = rating_up['User-ID'].astype('category').cat.codes
rating_up['book_index'] = rating_up['Book-Title'].astype('category').cat.codes

# %%
user_book_matrix = csr_matrix(
    (rating_up['Book-Rating'], (rating_up['user_index'], rating_up['book_index']))
)
print(f"User-Book Matrix Shape: {user_book_matrix.shape}")
# Out:
# User-Book Matrix Shape: (92106, 241071)

# %%
from sklearn.neighbors import NearestNeighbors 

user_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=10, n_jobs=-1) 
user_knn.fit(user_book_matrix) 

distances, indices = user_knn.kneighbors(user_book_matrix[3], n_neighbors=5) 
print(indices) 
print(distances)
# Out:
# [[92088 92089 92090 92091 92092]]
# [[1. 1. 1. 1. 1.]]

# %%
# This mapping is created to link the internal index of the user book matrix to user id.
user_id_mapping = dict(enumerate(rating_up['User-ID'].astype('category').cat.categories))

# This mapping is created to link the internal index of the user book matrix to book title
book_title_mapping = dict(enumerate(rating_up['Book-Title'].astype('category').cat.categories))

similar_users = [user_id_mapping[i] for i in indices.flatten()]

# %%
book_title_mapping
# Out:
# {0: ' A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)',
#  1: ' Always Have Popsicles',
#  2: " Apple Magic (The Collector's series)",
#  3: ' Ask Lily (Young Women of Faith: Lily Series, Book 5)',
#  4: ' Beyond IBM: Leadership Marketing and Finance for the 1990s',
#  5: ' Clifford Visita El Hospital (Clifford El Gran Perro Colorado)',
#  6: ' Dark Justice',
#  7: ' Deceived',
#  8: ' Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth',
#  9: ' Final Fantasy Anthology: Official Strategy Guide (Brady Games)',
#  10: ' Flight of Fancy: American Heiresses (Zebra Ballad Romance)',
#  11: ' Garfield Bigger and Better (Garfield (Numbered Paperback))',
#  12: " God's Little Promise Book",
#  13: ' Good Wives: Image and Reality in the Lives of Women in Northern New England, 1650-1750',
#  14: ' Goosebumps Monster Edition 1: Welcome to Dead House, Stay Out of the Basement, and Say Cheese and Die!',
#  15: ' Harry Potter and the Bible: The Menace Behind the Magick (And the Bible Series)',
#  16: ' Highland Desire (Zebra Splendor Historical Romances)',
#  17: ' Hiking the California Coastal Trail: Oregon to Monterey',
#  18: ' It Takes Two',
#  19: ' LA Gallinita Roja/the Little Red Hen',
#  20: ' Little Comic Shop of Horrors (Give Yourself Goosebumps, Book 17)',
#  21: ' Microsoft Application Architecture For Microsoft .net: Designing Application (Pro-Other)',
#  22: ' Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))',
#  23: ' Mystery Mile',
#  24: ' Nonbook Materials: The Organization of Integrated Collections',
#  25: " Pokemon: The Official Collector's Sticker Book",
#  26: ' Q-Space (Star Trek The Next Generation, Book 47)',
#  27: ' Q-Zone (Star Trek The Next Generation, Book 48)',
#  28: ' Stories of an Imaginary Childhood',
#  29: ' Summonings: Books of Magic, Vol. 2',
#  30: ' Tales of Terror and Suspense',
#  31: ' The Secret of the Old Clock (Nancy Drew, Book 1)',
#  32: " The Tender Commandments : Reflections on the Father's Love",
#  33: ' The Town Cats and Other Tales',
#  34: ' This Place Has No Atmosphere (Laurel-Leaf Books)',
#  35: ' Tough Loser',
#  36: ' Travel Companion Chile and Easter Island (Travel Companion)',
#  37: ' Twenty Thousand Leagues Under the Sea (Illustrated Classics)',
#  38: ' Weird News Stories',
#  39: ' Zap!: Science Fair Surprise! (Abracadabra!, Book 5)',
#  40: ' the Devil Will Drag You Under',
#  41: '!%@ (A Nutshell handbook)',
#  42: '!Arriba! Comunicacion y cultura',
#  43: '!Trato hecho!: Spanish for Real Life, Combined Edition',
#  44: '!Yo!',
#  45: '$14 In The Bank (Cathy Collection)',
#  46: '$30 Film School',
#  47: '$Weet Deal$',
#  48: "$oft Money: The True Power in Our Nation's Capital",
#  49: "' Allo 'Allo: the War Diaries of Rene Artois",
#  50: "' L' Is for Lawless",
#  51: "' Mein verwundetes Herz'. Das Leben der Lilli Jahn 1900 - 1944.",
#  52: "' Sehr geehrtes Arschloch.' Briefe an den RegierungsprÃ?Â¤sidenten.",
#  53: "' Sie belieben wohl zu scherzen, Mr. Feynman.'. Abenteuer eines neugierigen Physikers.",
#  54: "' Small g'. Eine Sommeridylle.",
#  55: "' Til the Fat Lady Sings",
#  56: "' Tis",
#  57: "'48",
#  58: "'A Hell of a Place to Lose a Cow': An American Hitchhiking Odyssey",
#  59: "'California Historical Landmarks'",
#  60: "'Das geht alles von Ihrer Zeit ab.'",
#  61: "'Eine gute Frau hat keinen Kopf'. EuropÃ?Â¤ische SprichwÃ?Â¶rter Ã?Â¼ber Frauen.",
#  62: "'G' Is for Grafton : The World of Kinsey Millhone",
#  63: "'Gentlemen Prefer Blondes' 'but Gentlemen Marry Brunettes'",
#  64: "'Isms: a dictionary of words ending in -ism, -ology, and -phobia,: With some similar terms, arranged in subject order",
#  65: "'Mater Biscuit : A Homegrown Novel",
#  66: "'Mit Verlaub, Sie sind ein Arschloch.' Joschkas schÃ?Â¤rfste SprÃ?Â¼che.",
#  67: "'N SYNC: TEARIN' UP THE CHARTS",
#  68: "'N Sync",
#  69: "'N Sync With JC",
#  70: "'N Sync With Justin",
#  71: "'N Sync: Tearing Up Our Hearts",
#  72: "'O Au No Keia: Voices from Hawai'I's Mahu and Transgender Communities",
#  73: "'Romance of Paula Vaughn'",
#  74: "'Round the Corner (Sister Circle)",
#  75: "'Salem's Lot",
#  76: "'Scope Out Your Life: What Your Sign Says About You (All about You (Scholastic))",
#  77: "'The Moon by Whale Light: And Other Adventures Among Bats, Penguins, Crocodilians, and Whales",
#  78: "'Til Death Do Us Part",
#  79: "'Til There Was You",
#  80: "'Til There Was You (Special Edition, No 576)",
#  81: "'Til We Meet Again (The Circle) (Silhouette Shadows, No 60)",
#  82: "'Tis Herself : A Memoir",
#  83: "'Tis The Season (Christmas Anthology): Under the Mistletoe/A Baby for Christmas/Christmas Angel/Home for Christmas",
#  84: "'Tis The Season (Harlequin Historical Series, No. 583)",
#  85: "'Tis The Season (Harlequin Temptation, No 278)",
#  86: "'Tis The Season (The Daddy School) (Superromance, 952)",
#  87: "'Tis the Season to Be Crabby (Festive Peanuts)",
#  88: "'Tis: A Memoir",
#  89: "'Twas The Night (Harlequin Desire No 684)",
#  90: "'Twas the Night Before Christmas",
#  91: "'Webster's New Business Writer's Guide (Webster's Dictionary Series)",
#  92: "'n Hollandse stadsguerrilla: Terugblik op de Rode Jeugd",
#  93: "'night, Mother : A Play (Mermaid Dramabook)",
#  94: "'til the Real Thing Comes Along",
#  95: '(George)',
#  96: "(Quinn's Way (Harlequin American Romance, No. 558)",
#  97: '(Un)arranged Marriage',
#  98: '* * *: A Novel',
#  99: '--Olivetti, Moulinex, Chaffoteaux et Maury (Quaderns crema. Narrativa)',
#  100: '--Und morgen die ganze Welt?: Rechstextreme Publizistik in Westeuropa',
#  101: '--fast ein Meisterwerk: Die Welt der Musik in Anekdoten : eine heitere Musik-Soziologie',
#  102: '--men i hvert fald i live',
#  103: '--y los 40 ladrones (ColecciÃ³n FÃ¡bula)',
#  104: '... And for Starters',
#  105: '... steigen aus... maschine brennt... 10 Fliegergeschichten.',
#  106: '... vol ... Ã\xa0 bord ... du.Concordia (Her Les Aventures de Michel Labre)',
#  107: '... wenn du es nicht lassen kannst.',
#  108: '...AND THE HORSE HE RODE IN ON : THE PEOPLE V. KENNETH STARR',
#  109: '...And Ladies of the Club',
#  110: '...And Now Miguel',
#  111: '...And The FAT Came Back',
#  112: '...Sacrifice of Angels:  The Dominion War Book 4 (Star Trek Deep Space Nine)',
#  113: '...and Conflict (Sugar Secrets S.)',
#  114: '.44',
#  115: '.44 (Leisure Western)',
#  116: '.Hack: //Legend of the Twilight, Vol. 1',
#  117: '.Hack: //Legend of the Twilight, Vol. 2',
#  118: '.NET Framework Essentials, 3rd Edition',
#  119: '006781: Bk.1 Gags De Boule Et Bil',
#  120: '007 El Mundo Nunca Es Suficiente',
#  121: '01-01-00: A Novel of the Millennium',
#  122: '01-01-00: The Novel of the Millennium',
#  123: '03 NODDY AND HIS CAR',
#  124: '0373953194 Christmas Stories 1993',
#  125: '06 Henry The Green Engine',
#  126: '08/15 Heute',
#  127: "09/11 8:48 am: Documenting America's Greatest Tragedy",
#  128: '1 + 2=4: Das Gigelchen geht in die Schule',
#  129: '1 2 3 Board Book',
#  130: '1 2 3 Draw Cars, Trucks, and Other Vehicles: A Step-By-Step Guide (1-2-3 Draw)',
#  131: '1 GENERATION AFTER',
#  132: '1 Mans Homestead (Illus)',
#  133: '1 Pot Meals',
#  134: '1 RAGGED RIDGE ROAD',
#  135: '1 World',
#  136: '1 x Jenseits, einfache Fahrt. Chili.',
#  137: '1+1+1 Une RÃ?Â©volution',
#  138: '1, 2, 3',
#  139: '1, 2, 3, Music!',
#  140: '1, 2, 3-- The Toddler Years: A Practical Guide for Parents and Caregivers',
#  141: '1, 2, 3: NURSERY BOARD BOOKS (Nursery Board Books)',
#  142: '1,000 Makers of the Millennium: The Men and Women Who Have Shaped the Last 1,000 Years',
#  143: '1,000 Marbles: A Little Something About Precious Time',
#  144: '1,000 More Jokes for Kids',
#  145: '1,000 Nursing Tips and Timesavers: Quick and Easy Tips for Improving Patient Care',
#  146: '1,000 Places to See Before You Die',
#  147: '1,000 Vegetarian Recipes',
#  148: '1,000 Years, 1,000 People: Ranking the Men and Women Who Shaped the Millennium',
#  149: '1,000 beautiful house plants and how to grow them',
#  150: '1,000,001 Things That Make You Crabby: The Official Checklist for Complainers, Ranters, Ravers and Bellyachers, and Everybody Else',
#  151: '1,001 Advertising Cuts from the Twenties and Thirties (Dover Pictorial Archive Series)',
#  152: '1,001 Computer Hints &amp; Tips: An A-To-Z Guide to Making the Most of Your Computer and the Internet',
#  153: '1,001 Facts Somebody Screwed Up',
#  154: '1,001 Great Gifts',
#  155: '1,001 Great Jokes/from the Delightfully Droll to the Truly Tasteless',
#  156: '1,001 Great Pet Jokes',
#  157: '1,001 Great Pick-Up Lines',
#  158: '1,001 Health Tips',
#  159: '1,001 Health-Care Questions Women Ask',
#  160: '1,001 Home Health Remedies for Seniors',
#  161: '1,001 Ideas for Science Projects',
#  162: '1,001 Low-Fat Vegetarian Recipes, 2nd ed.',
#  163: '1,001 Old-Time Garden Tips: Timeless Bits of Wisdom on How to Grow Everything Organically, from the Good Old Days When Everyone Did',
#  164: '1,001 Perfectly Legal Ways to Get Exactly What You Want, When You Want It, Every Time',
#  165: '1,001 Things Everyone Should Know About American History',
#  166: "1,001 Things to Do When There's Nothing to Do",
#  167: '1,001 Ways to Keep Customers Coming Back: Wow Ideas That Make Customers Happy and Will Increase Your Bottom Line',
#  168: '1,001 Ways to Save the Planet',
#  169: '1,003 Great Things About America',
#  170: '1,003 Great Things About Friends',
#  171: '1,003 Great Things About Getting Older',
#  172: '1,003 Great Things About Kids',
#  173: '1,003 Great Things About Teachers',
#  174: '1,2,3 To the Zoo: A Counting Book',
#  175: '1,337 Spot Illustrations of the Twenties and Thirties (Dover Pictorial Archive)',
#  176: '1,401 Even More Things That P*Ss Me Off',
#  177: '1,401 More Things That P*Ss Me Off',
#  178: '1,410 Quintessential Quizzes',
#  179: '1,440 Reasons To Quit Smoking : One for Every Minute of the Day...and Night',
#  180: '1,911 Best Things Anybody Ever Said',
#  181: '1-2-3',
#  182: '1-2-3 Draw Dinosaurs and Other Prehistoric Animals (123 Draw)',
#  183: '1-2-3 Draw Knights Castles &amp; Dragons: A Step by Step Guide (1-2-3 Draw)',
#  184: '1-2-3 Draw Pets and Farm Animals: A Step by Step Guide (123 Draw)',
#  185: '1-2-3 Draw Wild Animals: A Step by Step Guide (123 Draw)',
#  186: '1-2-3 Magic : Effective Discipline for Children 2-12',
#  187: '1-2-3 Magic: Effective Discipline for Children 2-12',
#  188: "1-2-3 Push! (The Little Dinosaurs' Adventures)",
#  189: '1-4-3 Means I Love You',
#  190: '1-800-Am-I-Nuts?',
#  191: '1-900-Dead',
#  192: '10 American History Plays for the Classroom (Grades 4-8)',
#  193: "10 Bad Choices That Ruin Black Women's Lives",
#  194: "10 Basic Steps Toward Christian Maturity (Leader's Guide)",
#  195: '10 Commandments Of Dating',
#  196: '10 Days to Faster Reading',
#  197: '10 Dumbest Mistakes Smart People Make and How To Avoid Them : Simple and Sure Techniques for Gaining Greater Control of Your Life',
#  198: '10 Feet Tall and Bulletproof',
#  199: '10 Gebote fÃ?Â¼r anspruchsvolle Frauen.',
#  200: '10 Keys for Unlocking the Bible: Treasures That Will Change Your Life',
#  201: '10 LITTLE INDIANS',
#  202: '10 Lb Penalty',
#  203: '10 Lb. Penalty',
#  204: '10 Minute Guide to Excel 4',
#  205: '10 Minute Guide to Excel 97 (10 Minute Guides (Computer Books))',
#  206: '10 Minute Guide to HTML 3.2',
#  207: '10 Minute Guide to Html',
#  208: '10 Minute Guide to Html 4.0 (Ten Minute Guide to...)',
#  209: '10 Minute Guide to Html Style Sheets (Ten Minute Guide Series)',
#  210: '10 Minute Guide to Lotus Notes Mail 4.6 (Ten Minute Guide to...)',
#  211: '10 Minute Guide to Norton Desktop for Windows',
#  212: '10 Minute Guide to PC Computing (Ten Minute Guide to...)',
#  213: '10 Minute Guide to Paying for Grad School (10 Minute Guides)',
#  214: '10 Minute Guide to Windows 3.1 (10 Minute Guide Series)',
#  215: '10 Minute Guide to Windows 95',
#  216: '10 Minute Marketing - A Daily Routine for Success (Book, Video, Cassette, &amp; Disk/Windows)',
#  217: '10 Minutes Till Bedtime',
#  218: '10 Minutue Guide to WordPerfect for Windows',
#  219: '10 Most Common Mistakes Good Parents Make: And How to Avoid Them',
#  220: '10 Natural Laws of Successful Time and Life Management',
#  221: "10 Of Today's Most Innovative Churches: What They're Doing, How They're Doing It and How You Can Apply Their Ideas in Your Church",
#  222: "10 Principles for Spiritual Parenting: Nurturing Your Child's Soul",
#  223: '10 Real SATs, Third Edition',
#  224: '10 Real Sats (Serial)',
#  225: '10 Reasons to Abolish the Imf &amp; World Bank (Open Media Pamphlet Series)',
#  226: '10 Relatos Fantasticos',
#  227: '10 Secrets for Success and Inner Peace',
#  228: '10 Steps in Writing the Research Paper (10 Steps in Writing the Research Paper, 5th ed)',
#  229: '10 Steps to Home Ownership: A Workbook for First-Time Buyers',
#  230: '10 Stupid Things Women Do to Mess Up Their Lives',
#  231: '10 Things I Hate About You',
#  232: '10 Things You Should Know About Dinosaurs (10 Things You Should Know series)',
#  233: '10 Years of Matt',
#  234: '10 critical keys for highly effective Mormon families',
#  235: '10 steps in writing the research paper,',
#  236: '10, 000 Dreams Interpreted',
#  237: '10,000 Answers: The Ultimate Trivia Encyclopedia',
#  238: '10,000 Dreams Interpreted',
#  239: "10,000 Dreams Interpreted or What's in a Dream",
#  240: '10,000 Dreams Interpreted: A Complete Guide to the Meaning of Your Dreams',
#  241: '10,000 Garden Questions Answered by 20 Experts',
#  242: '10,000 Garden Questions: Answered by 20 Experts',
#  243: '10,000 Names for Your Baby',
#  244: '10,000 Things to Praise God for',
#  245: '10,000 Ways to Say I Love You: The Biggest Collection of Romantic Ideas Ever Gathered in One Place',
#  246: '10,000 dreams interpreted: A dictionary of dreams',
#  247: '10-20-30 Minutes to Quilt (Sewing with Nancy)',
#  248: '10-Minute Card Games',
#  249: '10-Minute Decorating: 176 Fabulous Shortcuts with Style',
#  250: '10-Minute Scrapbook Pages: Hundreds of Easy, Innovative Designs',
#  251: '100 Astounding Little Alien Stories',
#  252: '100 Banned Books: Censorship Histories of World Literature',
#  253: '100 Best Denver Area &amp; Front Range Day Hikes',
#  254: '100 Best Family Resorts in North America: 100 Quality Resorts With Leisure Activities for Children and Adults (The 100 Best Resorts)',
#  255: '100 Best Honeymoon Resorts of the World (The 100 Best Resorts Series)',
#  256: '100 Best Romantic Resorts of the World',
#  257: '100 Best TV Commercials: And Why They Worked',
#  258: '100 Best-Loved Poems (Dover Thrift Editions)',
#  259: '100 Bible Quiz Activities for Church School Classes',
#  260: '100 Billion Suns: The Birth, Life, and Death of the Stars',
#  261: '100 Birds and How They Got Their Names',
#  262: '100 Books for Girls to Grow On',
#  263: '100 Carols for Choirs',
#  264: '100 Christian Women Who Changed the Twentieth Century',
#  265: '100 Cross-Stitch Christmas Ornaments',
#  266: '100 Dastardly Little Detective Stories',
#  267: '100 Days in the Jungle',
#  268: '100 Days of Fun at School',
#  269: '100 Excuses for Kids',
#  270: '100 Favorite Flowering Shrubs (The 100 Favorite Series)',
#  271: '100 Flowers and How They Got Their Names',
#  272: '100 Gedichte ohne Vaterland (Wagenbachs TaschenbÃ¼cherei ; 44)',
#  273: '100 Geordie Jokes',
#  274: '100 Ghastly Little Ghost Stories',
#  275: '100 Glimpses into China',
#  276: '100 Great Archaeological Discoveries',
#  277: '100 Great Fantasy Short Short Stories',
#  278: '100 Great Fantasy Short, Short Stories',
#  279: '100 Great Kings Queens &amp; Rules',
#  280: '100 Great Natural Remedies: Using Healing Plants at Home',
#  281: '100 Great Operas and Their Stories',
#  282: '100 Great Problems of Elementary Mathematics: Their History and Solution',
#  283: '100 Great Science Fiction Short Short Stories',
#  284: '100 Great Soup, Stew &amp; Chili Recipes',
#  285: '100 Greatest Women',
#  286: '100 Hair Raising Little Horror Stories',
#  287: '100 Hikes in Colorado (100 Hikes Series)',
#  288: '100 Hikes in the Alps',
#  289: '100 Hilarious Little Howlers',
#  290: '100 Local Heroes',
#  291: '100 Magic Tricks',
#  292: '100 Malicious Little Mysteries',
#  293: '100 Monologues: An Audition Sourcebook from New Dramatists',
#  294: '100 Most Important Women of the 20th Century',
#  295: "100 One-Night Reads: A Book Lover's Guide",
#  296: '100 Plants for Quick Growing Gardens',
#  297: '100 Poems Without a Country (German Poetry)',
#  298: '100 Poems by 100 Poets: An Anthology',
#  299: '100 Questions Every First-Time Home Buyer Should Ask : With Answers from Top Brokers from Around the Country',
#  300: '100 Questions Every First-Time Home Buyer Should Ask: With Answers from Top Brokers from Around the Country',
#  301: '100 Questions You Should Ask About Your Personal Finances: And the Answers You Need to Help You Save, Invest, and Grow Your Money',
#  302: '100 Questions and Answers: Dinosaurs (100 Questions and Answers Series)',
#  303: '100 Relationships That Shaped World History',
#  304: "100 Secrets of the Smokies: A Guide to the Best Undiscovered Places in the Great Smoky Mountains Area (The Savvy Traveler's Guide)",
#  305: '100 Selected Poems',
#  306: '100 Selected Poems by E. E. Cummings',
#  307: '100 Selected Stories (Wordsworth Classics)',
#  308: '100 Simple Secrets of Great Relationships : What Scientists Have Learned and How You Can Use It',
#  309: '100 Simple Secrets of Healthy People : What Scientists Have Learned and How You Can Use it (100 Simple Secrets)',
#  310: '100 Strokes of the Brush Before Bed (Black Cat Series)',
#  311: '100 TOP PSYCHICS IN AMERICA: THEIR STORIES SPECIALTIES &amp; HOW TO CONTACT THEM',
#  312: '100 Things Every Writer Needs to Know',
#  313: "100 Things I'm Not Going to Do Now That I'm over 50",
#  314: '100 Things to Always Remember and One Thing to Never Forget (Self-Help)',
#  315: "100 Things to Do Before You Die: Travel Events You Just Can't Miss",
#  316: '100 Thoughts That Lead to Happiness',
#  317: '100 Treasures of Buckingham Palace',
#  318: '100 Voices: Words That Shaped Our Souls Wisdom to Guide Our Future',
#  319: '100 Walks in Tasmania',
#  320: '100 Ways of Seeing an Unequal World',
#  321: '100 Ways to Attract Angels',
#  322: '100 Ways to Enhance Self-Concept in the Classroom: A Handbook for Teachers and Parents (Prentice-Hall Curriculum and Teaching Series)',
#  323: '100 Ways to Keep Your Soul Alive (Living Deeply and Fully Every Day)',
#  324: '100 Ways to Keep Your Soul Alive : Living Deeply and Fully Every Day',
#  325: '100 Ways to Motivate Yourself',
#  326: '100 Ways to Motivate Yourself: Change Your Life Forever',
#  327: '100 Ways to Overcome Depression',
#  328: '100 Weekend Cross-Stitch Gifts',
#  329: '100 Words About Animals',
#  330: '100 Words Every High School Graduate Should Know',
#  331: '100 Years of American Newspaper Comics: An Illustrated Encyclopedia',
#  332: '100 Years of Oz: A Century of Classic Images from the Wizard of Oz Collection of Willard Carroll',
#  333: '100 Years: 100 Stories',
#  334: '100 greatest golf courses--and then some',
#  335: '100 hikes in the North Cascades: Mt. Baker area, North Cascades NP, Ross Lake NRA, Pasayten Wilderness, Methow-Chelan',
#  336: '100 hikes in the South Cascades and Olympics',
#  337: '100 op de schaal van lief: Gedichten &amp; liedteksten',
#  338: '100 years of the Wimbledon tennis championships',
#  339: '100% American',
#  340: '100% Chocolate',
#  341: '100% Hero (Spotlight)',
#  342: '100% True!',
#  343: '100.000 Kilometros Tras Los Ovnis (Los Jet De Plaza &amp; Janes)',
#  344: '1000 Crazy Jokes for Kids',
#  345: '1000 Dogs (Klotz)',
#  346: '1000 Facts About Space',
#  347: '1000 Facts About Wild Animals',
#  348: '1000 Facts About the Earth (1000 Facts about)',
#  349: '1000 Forbidden Pictures',
#  350: '1000 Gefahren. Die Insel der 1000 Gefahren.',
#  351: '1000 Gefahren. Die Juwelen von Nabooti.',
#  352: '1000 Gefahren. Die Spur des BÃ?Â¤ren. ( Ab 10 J.).',
#  353: '1000 Gefahren. Katastrophentag.',
#  354: '1000 Great Quilt Blocks (That Patchwork Place)',
#  355: '1000 Jokes for Kids of All Ages',
#  356: '1000 Knock Knock Jokes for Kids',
#  357: '1000 Most Challenging Words',
#  358: '1000 Paths to Zen',
#  359: '1000 Photo Icons',
#  360: '1000 Play Thinks: Puzzles, Paradoxes, Illusions &amp; Games',
#  361: '1000 Questions About Canada',
#  362: '1000 Questions and Answers',
#  363: '1000 Tattoos (Klotz)',
#  364: '1000 neue Dinge, die man bei Schwerelosigkeit tun kann.',
#  365: '10000 Dreams Interpreted',
#  366: '10000 Garden Questions Answered',
#  367: '1001 Activities for a Smarter Child',
#  368: '1001 Beauty Solutions: The Ultimate One-Step Adviser for Your Everyday Beauty Problems',
#  369: '1001 Brilliant Ways to Checkmate',
#  370: '1001 Cookie Recipes',
#  371: '1001 Four-Ingredient Recipes',
#  372: '1001 Free Goodies and Cheapies',
#  373: '1001 Hints &amp; Tips for Your Garden : An Indispensable Guide to Easier and More Effective Gardening',
#  374: '1001 Ideas to Create Retail Excitement',
#  375: '1001 More Ways to Be Romantic',
#  376: '1001 Muffins, Biscuits, Doughnuts, Pancakes, Waffles, Popovers, Fritters, Scones and Other Quick Breads',
#  377: '1001 Natural Remedies',
#  378: '1001 Oriental Recipes',
#  379: '1001 Pitfalls in French (1001 Pitfalls Series)',
#  380: '1001 Questions Answered About Earthquakes, Avalanches, Floods, and Other Natural Disasters',
#  381: '1001 Really Cool Web Sites',
#  382: '1001 Secrets for Windows Nt Registry',
#  383: '1001 Simple Ways to Lose Weight: Proven Tips for Losing Those Extra Pounds-- And Keeping Them of',
#  384: '1001 Spot Illustrations of the Lively Twenties (Dover Pictorial Archive Series)',
#  385: '1001 Texas Place Names',
#  386: '1001 Things Everyone Should Know About African American History',
#  387: '1001 Things Everyone Should Know About Science',
#  388: "1001 Things Everyone Should Know About Women's History",
#  389: '1001 Things Everyone Should Know About the South',
#  390: '1001 Things Everyone Should Know About the Universe',
#  391: '1001 Things to Do With Your Kids',
#  392: '1001 Ways To Save Money . . . and Still Have a Dazzling Wedding',
#  393: '1001 Ways to Be Romantic',
#  394: '1001 Ways to Celebrate America',
#  395: '1001 Ways to Cut Your Expenses',
#  396: '1001 Ways to Energize Employees',
#  397: '1001 Ways to Reveal Your Personality',
#  398: '1001 Ways to Reward Employees',
#  399: '1001 Ways to Save Money ... and Still Have a Dazzling Wedding',
#  400: '1001 maximes de motivation',
#  401: '1001 pitfalls in Spanish,',
#  402: '1001 valuable things you can get free',
#  403: '1002 Ways to Waste Your Working Time',
#  404: '1008 Secrets of a Happy Marriage',
#  405: '101 Amazing Things about God',
#  406: '101 Back to School Jokes',
#  407: '101 Best Cheers: How to Be the Best Cheerleader Ever',
#  408: '101 Best Dot.Coms to Start: The Essential Sourcebook of Startup Wisdom, Financial Tips, and Inside Secrets for Building a Business on the Internet',
#  409: '101 Best Extra-Income Opportunities for Women',
#  410: '101 Best Family Card Games',
#  411: '101 Best Home-Based Businesses for Women',
#  412: '101 Bossy Cow Jokes',
#  413: '101 Bright Ideas: Esl Activities for All Ages',
#  414: '101 Bug Jokes',
#  415: '101 Business You Can',
#  416: '101 Cat and Dog Jokes',
#  417: '101 Common Therapeutic Blunders',
#  418: '101 Commonsense Rules for Making Things Happen: How to Make Plans and Implement Projects (How-To Guides)',
#  419: '101 Corporate Haiku',
#  420: '101 Cose De Vedere E Fare in Irlanda',
#  421: '101 Creepy Creature Jokes',
#  422: '101 Dalmatians',
#  423: '101 Dalmatians (Pictureback Books (Paperback))',
#  424: '101 Dalmatians (Sight &amp; Sound)',
#  425: '101 Dalmatians : Escape from De Vil Mansion',
#  426: '101 Dalmatians: Proud to Be a Pup',
#  427: '101 Dalmatians: What If Cruella De Vil was Your Lunch Lady?',
#  428: '101 Dalmations',
#  429: "101 Dalmations - Collector's Edition (Illustrated Classic)",
#  430: '101 Dinosaur Jokes',
#  431: '101 Do-It-Yourself Projects',
#  432: '101 Educational Conversations With Your 3rd Grader (101 Educational Conversations You Should Have With Your Child)',
#  433: '101 Essential Tips on Photography (101 Essential Tips)',
#  434: '101 Essential Tips on Video',
#  435: '101 Essential Tips: Aquarium Fish',
#  436: '101 Essential Tips: Baby Care',
#  437: '101 Essential Tips: Basic Gardening',
#  438: '101 Essential Tips: Basic Meditation',
#  439: '101 Essential Tips: Bonsai',
#  440: '101 Essential Tips: Chicken',
#  441: '101 Essential Tips: Cooking With Spices (101 Essential Tips)',
#  442: '101 Essential Tips: Healthy Living',
#  443: '101 Essential Tips: House Plants',
#  444: '101 Ethical Dilemmas',
#  445: '101 Experiments in the Philosophy of Everyday Life',
#  446: '101 Famous Poems',
#  447: '101 Favorite Cat Poems',
#  448: '101 Feng Shui Tips for Your Home',
#  449: '101 French Proverbs',
#  450: '101 Full-Size Quilt Blocks and Borders',
#  451: '101 Fun Things to Do on the Texas Coast',
#  452: '101 Funny Bunny Jokes',
#  453: '101 Great American Poems (Dover Thrift Editions)',
#  454: '101 Great Answers to the Toughest Interview Questions (3rd ed)',
#  455: '101 Great Answers to the the Toughest Financial Questions',
#  456: '101 Great Lowfat Mexican Dishes: Hot, Spicy &amp; Healthful',
#  457: '101 Great Mail-Order Businesses: The Very Best (And Most Profitable!) Mail-Order Businesses You Can Start With Little or No Money',
#  458: '101 Great Nature Experiments',
#  459: '101 Great Resumes',
#  460: '101 Great Science Experiments',
#  461: '101 Grunde Kein Ossi Zu Sein',
#  462: '101 Hamburger Jokes',
#  463: '101 Holiday Jokes',
#  464: '101 Hopelessly Hilarious Jokes',
#  465: '101 Inspirational Stories of the Rosary',
#  466: '101 Jr Book CL: Autob',
#  467: '101 Killer Apps for Your Pocket PC (101 Killer Apps)',
#  468: '101 Law Forms for Personal Use, Third Edition',
#  469: '101 Lies Men Tell Women -- And Why Women Believe Them',
#  470: '101 Marvelous Money-Making Ideas For Kids',
#  471: '101 Most Powerful Proverbs in the Bible (101 Most Powerful Series)',
#  472: '101 Most Powerful Verses in the Bible',
#  473: '101 Nights of Grrreat Sex',
#  474: '101 Nutty Nature Jokes',
#  475: '101 Outdoor Adventures: Great Things to Do Under the Sun (And the Stars)',
#  476: '101 Outer Space Jokes (101 Joke Book)',
#  477: '101 Perfect Chocolate Chip Cookies',
#  478: '101 Pet Jokes',
#  479: '101 Philosophy Problems',
#  480: '101 Poems Against War',
#  481: '101 Poems That Could Save Your Life : An Anthology of Emotional First Aid',
#  482: '101 Poems to Get You Through the Day (and Night)',
#  483: '101 President Jokes',
#  484: '101 Promises Worth Keeping (For Men Only)',
#  485: '101 Questions Children Ask about God (Questions Children Ask)',
#  486: '101 Questions Your Cat Would Ask Its Vet (If Your Cat Could Talk)',
#  487: '101 Questions Your Cat Would Ask Its Vet: If Your Cat Could Talk',
#  488: "101 Questions Your Cat Would Ask: What's Bothering Your Cat and How to Solve Its Problems",
#  489: '101 Questions Your Dog Would Ask Its Vet (If Your Dog Could Talk)',
#  490: '101 Questions and Answers on Buddhism',
#  491: '101 Questions and Answers on Islam',
#  492: '101 Quick Tips to Make Your Home Feel Sensesational',
#  493: '101 Quick Tips to Make Your Home Look Sensesational',
#  494: '101 Quick Tips to Make Your Home Smell Sensesational',
#  495: '101 Quick Tips to Make Your Home Sound Sensesational',
#  496: '101 Quick Tips to Make Your Home Taste Sensesational',
#  497: '101 Quizzlers (Mind Benders and Fun Facts Series)',
#  498: '101 Reasons Why Cats Make Great Kids',
#  499: '101 Reasons Why a Cat Is Better Than a Man',
#  500: '101 Reasons for Time-out in Kindergarten &amp; Preschool',
#  501: '101 Reasons to READ to Your Child',
#  502: '101 Reykjavik',
#  503: '101 ReykjavÃ\xadk: A Novel',
#  504: '101 Rock and Roll Jokes and Riddles',
#  505: '101 Safe Internet Sites for Kids',
#  506: '101 Salivations: For the Love of Dogs',
#  507: '101 School Cafeteria Jokes',
#  508: '101 School Jokes',
#  509: '101 Science Projects (Troll Teacher Idea Books)',
#  510: '101 Secrets A Cool Mom Knows',
#  511: '101 Shaggy Dog Stories',
#  512: '101 Silly Monster Jokes',
#  513: '101 Silly Summertime Jokes',
#  514: '101 Simple Ways to Be Good to Yourself: How to Discover Peace and Joy in Your Life',
#  515: '101 Spooky Halloween Jokes',
#  516: '101 Stressed Out',
#  517: '101 Super Sports Jokes',
#  518: '101 Survival Secrets: How to Make $1,000,000, Lose 100 Pounds, and Just Plain Live Happily',
#  519: '101 Tax Loopholes for the Middle Class',
#  520: '101 Telephone Jokes',
#  521: '101 Thanksgiving Knock-Knocks, Jokes, and Riddles',
#  522: "101 Things God Can't Do",
#  523: '101 Things Not to Say During Sex',
#  524: "101 Things You Can Do for Our Children's Future",
#  525: "101 Things You Don't Know About Science and No One Else Does Either",
#  526: '101 Things to Do With Your Computer (Usborne Computer Guides)',
#  527: '101 Things to Do With a Cake Mix',
#  528: '101 Things to Do in the Year 2000',
#  529: "101 Things to Do to Develop Your Child's Gifts and Talents/for Children Ages 3-6",
#  530: '101 Training Tips for Your Cat',
#  531: '101 Training Tips for Your Dog',
#  532: '101 Unuseless Japanese Inventions',
#  533: '101 Unuseless Japanese Inventions: The Art of Chindogu',
#  534: '101 Uses for This Book',
#  535: '101 Uses for a Bridesmaid Dress',
#  536: '101 Uses for a Dead Cat',
#  537: '101 Uses for a Lab',
#  538: '101 Uses for an Ex-Husband',
#  539: '101 Vacation Jokes',
#  540: '101 Valentine Jokes',
#  541: '101 Vegetarian Delights',
#  542: '101 Wacky Camping Jokes',
#  543: '101 Wacky Computer Jokes',
#  544: '101 Wacky Facts About Bugs and Spiders',
#  545: '101 Wacky Facts About Kids',
#  546: '101 Wacky Facts About Mummies',
#  547: '101 Wacky Facts About Snakes &amp; Reptiles',
#  548: '101 Wacky Kid Jokes',
#  549: '101 Wacky Sports Quotes',
#  550: '101 Wacky State Jokes',
#  551: '101 Ways To Boost Your Math Skills',
#  552: '101 Ways To Boost Your Science Skills',
#  553: '101 Ways Your Church Can Change the World: A Guide to Help Christians Express the Love of Christ to a Needy World',
#  554: '101 Ways to Avoid Reincarnation: Or Getting It Right the First Time',
#  555: '101 Ways to Avoid Spelling Traps',
#  556: '101 Ways to Be a Special Dad',
#  557: '101 Ways to Be a Special Mom',
#  558: '101 Ways to Bug Your Parents',
#  559: '101 Ways to Count Sheep: Or Holy Cow Not Another Sheep!',
#  560: '101 Ways to Date Your Mate',
#  561: '101 Ways to Do Better in School',
#  562: '101 Ways to Feed the Heart',
#  563: '101 Ways to Flirt: How to Get More Dates and Meet Your Mate',
#  564: '101 Ways to Get Away With Anything! (Malcolm in the Middle)',
#  565: "101 Ways to Get Straight A's (101 Ways)",
#  566: '101 Ways to Juice It!: Luscious Receipes and the Best and Most Comprehensive Guide to Fruit and Vegetable Juicing',
#  567: '101 Ways to Make Every Second Count: Time Management Tips and Techniques for More Success With Less Stress',
#  568: '101 Ways to Make Money at Home',
#  569: '101 Ways to Make Your Child Feel Special',
#  570: '101 Ways to Promote Your Web Site: Filled With Proven Internet Marketing Tips, Tools, Techniques, and Resources to Increase Your Web Site Traffic',
#  571: '101 Ways to Read with Speed and Understanding',
#  572: '101 Ways to Recession-Proof Your Career',
#  573: '101 Ways to Start Your Own Business',
#  574: '101 Ways to Win Homecoming Queen (Three of a Kind, No 6)',
#  575: '101 Ways to Your Husbands Heart/Wifes Heart',
#  576: '101 Ways/Meet MR Rt (Bantam Sweet Dreams Romances)',
#  577: '101 Word Games for Students of English As a Second or Foreign Language (Resource Books for Teachers of Young Students)',
#  578: '101 cuentos clÃ¡sicos de la China',
#  579: '101 expÃ?Â©riences de philosophie quotidienne',
#  580: '101 uses for an unused home computer',
#  581: '102 1/2 Uses for an Extraterrestrial',
#  582: '102 Animal Jokes',
#  583: '102 Creepy, Crawly Bug Jokes',
#  584: '102 Dalmatians',
#  585: '102 Goofy Jokes',
#  586: '102 Haunted House Jokes',
#  587: '102 Out-Of-This-World Jokes',
#  588: '102 Questions Children Ask about the Bible (Questions Children Ask)',
#  589: '102 School Cafeteria Jokes',
#  590: '102 School Jokes',
#  591: '102 Wacky Monster Jokes',
#  592: '102 Wild and Wacky Jokes',
#  593: '103 Hikes: In Southwestern British Columbia',
#  594: '103 Questions Children Ask about Right from Wrong (Questions Children Ask)',
#  595: '104 Activities That Build: Self-esteem, Teamwork, Communication, Anger Management, Self-discovery, and Coping Skills',
#  596: '1066 &amp; All That: A Memorable History of England',
#  597: '1066: The Year of the Conquest',
#  598: '107 Questions Children Ask about Prayer (Questions Children Ask)',
#  599: '10th Grade : A Novel',
#  600: '10th Grade: A Novel',
#  601: '10th Kingdom',
#  602: '11 : 11: Inside the Doorway',
#  603: '11 Edward Street',
#  604: '11 Eleven: Witnessing the World Trade Center 1974-2001',
#  605: '11 Harrow House',
#  606: '11 Harrowhouse',
#  607: "11 Septembre 2001 : L'effroyable imposture",
#  608: '11 Settembre. LA Ragioni Di Chi',
#  609: '110 Shanghai Road',
#  610: '110%: 110 Strategies for Feeling Great Every Day',
#  611: '110. street-eko geltokia (Literatura beltza)',
#  612: '117 Days Adrift (World of Cruising)',
#  613: '1185 Park Avenue',
#  614: '1185 Park Avenue: A Memoir',
#  615: '119 Years of the Atlantic',
#  616: '11th Hour',
#  617: '12 Again',
#  618: '12 Days in Ghana: Reunions, Revelations &amp; Reflections',
#  619: '12 Days on the Road',
#  620: '12 Days on the Road: The Sex Pistols and America',
#  621: '12 Gothic Tales (Oxford Twelves)',
#  622: '12 Monkeys: A Novel',
#  623: '12 Mystery Stories (Oxford Twelves)',
#  624: '12 Philippine Women Writers (Philippine writers series)',
#  625: '12 Simple Secrets of Happiness at Work: Finding Fulfillment, Reaping Rewards',
#  626: '12 Simple Secrets of Happiness in a Topsy-Turvy World (12 Simple Secrets)',
#  627: '12 Simple Secrets of Happiness: Finding Joy in Everyday Relationships',
#  628: '12 Simple Steps To A Winning Marketing Plan',
#  629: '12 Step Prayer Book (Lakeside Meditation)',
#  630: '12 Steps and 12 Traditions',
#  631: '12 Steps to Living Without Fear',
#  632: '12 Steps to Raw Foods: How to End Your Addiction to Cooked Food',
#  633: '12 Steps: A Spiritual Journey (Tools for Recovery)',
#  634: '12 Stories',
#  635: '12 Stories for Late at Night',
#  636: '12 Victorian Ghost Stories',
#  637: '12 steps to living without fear',
#  638: '1215 : The Year of Magna Carta',
#  639: '122 Minutes a Month to Greater Profits',
#  640: '123 (The Anne Geddes Collection)',
#  641: '123 Slide and See',
#  642: '125 Brain Games for Babies',
#  643: '125 Brain Games for Toddlers and Twos: Simple Games to Promote Early Brain Development (125 Brain Games)',
#  644: '125 Cookies to Bake, Nibble, and Savor',
#  645: '125 Most Asked Questions About Cats (And the Answers)',
#  646: '125th Anniversary Commemorative Cookbook (Pennsylvania State Grange)',
#  647: '128 Ways to Say \\I Love You\\" to Your Cat"',
#  648: '12TH NIGHT',
#  649: '13',
#  650: '13 99 Euros',
#  651: '13 Cent Killers : The 5th Marine Snipers in Vietnam',
#  652: '13 Fatal Errors Managers Make and How You Can Avoid Them',
#  653: '13 Fatal Errors Managers Make, and How You Can Avoid Them',
#  654: '13 French Street and the Red Scarf',
#  655: '13 Ghosts: Strange But True Ghost Stories',
#  656: '13 Ghosts: Strange but True Stories',
#  657: '13 Going on 30',
#  658: '13 Murder Mysteries (Point Crime S.)',
#  659: '13 Royal Street (Silhoutte Intimate Moments, No 7447)',
#  660: '13 Scary Ghost Stories',
#  661: '13 Secrets for Speaking Fluent Japanese',
#  662: '13 Short Detective Novels',
#  663: '13 Short Espionage Novels',
#  664: "13 To 19: A Parent's Guide to Understanding the Teenage Years",
#  665: '13 [i.e. Dreizehn] unerwÃ¼nschte Reportagen: + Anhang, Verbotene AufrÃ¼stung, Giftgas fÃ¼r die Bundeswehr (Rororo Sachbuch)',
#  666: '131 Christians Everyone Should Know (Holman Reference)',
#  667: '13th Gen: Abort, Retry, Ignore, Fail?',
#  668: '13th Valley',
#  669: '14 Peck Slip',
#  670: '14 Valentine Place (Harlequin Superromance, No. 1035)',
#  671: '14 Vicious Valentines',
#  672: '14,000 Quips and Quotes for Writers and Speakers',
#  673: '14,000 Things to Be Happy About',
#  674: '14.99 Ã?Â?',
#  675: '140 neue Tipps fÃ?Â¼r tolle Chefs... ...und solche, die es werden wollen.',
#  676: '1421 : The Year China Discovered America',
#  677: '1421 The Year China Discovered America',
#  678: '1421. Als China die Welt entdeckte.',
#  679: '1421: The Year China Discovered America',
#  680: '147 Fun Things to do in Houston (5th Edition)',
#  681: '1492',
#  682: '15 Days of Prayer With Saint Faustina Kowalska',
#  683: "15 Houseplants Even You Can't Kill",
#  684: '15 Minute Devotions for Couples',
#  685: '15 Minute Family Traditions &amp; Memories',
#  686: '15 Minute Pilates: Body Maintenance to Make You Longer, Leaner and Stronger',
#  687: '15 Minutes Alone With God',
#  688: '15 Minutes of Peace With God',
#  689: "15 Months In Sog: A Warrior's Tour",
#  690: '15-Minute Low-Carb Recipes: Instant Recipes for Dinners, Desserts, and More',
#  691: '150 Most-Asked Questions About Menopause: What Women Really Want to Know',
#  692: '150 Solitaire Games',
#  693: '150 Vegan Favorites: Fresh, Easy, and Incredibly Delicious Recipes You Can Enjoy Every Day',
#  694: '158 POUND MARRIAGE',
#  695: '1587, A Year of No Significance',
#  696: '159 Celtic Designs (Dover Pictorial Archive)',
#  697: '16 Lighthouse Road',
#  698: '16 Uhr 50 ab Paddington.',
#  699: '1600 BÃ?Â¤uche.',
#  700: '1600 Ventres',
#  701: '1632 (Assiti Shards (Hardcover))',
#  702: '1632 (Assiti Shards (Paperback))',
#  703: '1633',
#  704: '1634 : The Galileo Affair (The Ring of Fire)',
#  705: '168/BUSINESS/ANYONE/',
#  706: '17 Lies That Are Holding You Back and the Truth That Will Set You Free',
#  707: '17 Secrets of the Master Prospectors',
#  708: '1700',
#  709: '1700: Scenes from London Life',
#  710: '175 Amazing Nature Experiments',
#  711: '175 Easy-To-Do Everyday  Crafts',
#  712: '175 Easy-To-Do Halloween Crafts',
#  713: '175 Easy-To-Do Thanksgiving Crafts (Creative Uses for Recyclables)',
#  714: '175 More Science Experiments to Amuse and Amaze Your Friends',
#  715: '1768 Encyclopaedia Britannica Replica: Add This Classic to Your Library Collection',
#  716: '1776: A Musical Play (Penguin Plays)',
#  717: '1776: Son of Liberty, Young Founders 3',
#  718: '1788: Comprising A narrative of the expedition to Botany Bay and A complete account of the settlement at Port Jackson',
#  719: '18 Best Stories by Edgar Allan Poe',
#  720: '18 WHEELS OF JUSTICE',
#  721: '18 Wheels of Justice',
#  722: '180 Days of Character',
#  723: '180 Degree Murder',
#  724: '1812',
#  725: '1812 (The American Story)',
#  726: '1846: Portrait of the Nation',
#  727: '1848, die ungewollte Revolution: Die revolutionÃ¤ren Bewegungen in Europa 1830-1849',
#  728: '1848: The Revolutionary Tide in Europe (Revolutions in the Modern World)',
#  729: '1870 Not With Our Blood (Young Founders Series)',
#  730: '1876',
#  731: '1876 (American Chronicle)',
#  732: '1876 a Novel',
#  733: '1876: A novel',
#  734: '1896 Boston Cooking-School Cookbook',
#  735: '1898: The Birth of the American Century',
#  736: '18Mm Blues',
#  737: '18th Century Lovers: A Book of Days',
#  738: '19 Purchase St.',
#  739: '19 Purchase Street',
#  740: '19 gifts of the spirit: Which do you have? Are you using them? (An input book)',
#  741: '1900 House',
#  742: '1901: A Novel',
#  743: '1912 Facts about Titanic',
#  744: '1915 the Death of Innocence',
#  745: '1916',
#  746: '1916: A Novel of the Irish Rebellion (Irish Century)',
#  747: '1919: Volume Two of the U.S.A. Trilogy',
#  748: '1921 : The Great Novel of the Irish Civil War (Irish Century)',
#  749: '1929',
#  750: '1933 WAS BAD YEAR',
#  751: '1939',
#  752: '1945 (Wing Commander)',
#  753: '1949 : A Novel of the Irish Free State (Irish Century)',
#  754: '1950: Crossroads of American Religious Life',
#  755: '1953: Chronicle of a Birth Foretold',
#  756: '1956 and all that: A memorable history of England since the war to end all wars (Two)',
#  757: '1959: A Novel',
#  758: '1968',
#  759: '1968 : The Year That Rocked the World',
#  760: '1968 In America: Music, Politics, Chaos, Counterculture and the Shaping of a Generation',
#  761: '1968 In America: Music, Politics, Chaos, Counterculture, and the Shaping of a Generation',
#  762: '1979.',
#  763: '1981 Guide to Coupons and Refunds',
#  764: '1984',
#  765: '1984 ( Neunzehnhundertvierundachtzig). JubilÃ?Â¤umsausgabe. Roman.',
#  766: '1984 (Cliffs Notes)',
#  767: "1984 (Everyman's Library)",
#  768: '1984 (Signet Classics (Paperback))',
#  769: '1984 (Spanish Language Edition)',
#  770: '1984 : a novel',
#  771: '1984 and Beyond',
#  772: '1984.',
#  773: '1984: Spring a Choice of Futures',
#  774: '1984: Spring: A Choice of Futures',
#  775: '1985: A Historical Report (Hong Kong 2036 from the Hungarian)',
#  776: '1987 What Color is Your Parachute?',
#  777: '1988',
#  778: '1988 Baseball Cards 120 Of T H',
#  779: '1988 South American Handbook (Footprint South American Handbook)',
#  780: '1989 Guinness Book of World Records (Guinness Book of World Records, 27th ed)',
#  781: '1989 Ireland',
#  782: '199 Great Home Businesses You Can Start (And Succeed in for Under $1,000)',
#  783: '199 Things to Do Over Summer Vacation',
#  784: "1990's Handbook: Modern Background for Cthulhu",
#  785: '1993 Yearbook of Astronomy',
#  786: "1994 Novel &amp; Short Story Writer's Market",
#  787: '1995 Information Please Sports Alman',
#  788: "1996 Poet's Market (Poet's Market, 1996)",
#  789: '1996-97 Texas Almanac and State Industrial Guide (Paper)',
#  790: "1997 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 1997)",
#  791: '1997 Cancer June 21-July 20: Day-By-Day Horoscope',
#  792: "1997 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 1997)",
#  793: "1997 Poet's Market (Poet's Market, 1997)",
#  794: "1998 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 1998)",
#  795: "1998 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 1998)",
#  796: '1998 Handbook of United States Coins: With Premium List (55th ed)',
#  797: '1998 Information Please Almanac (Serial)',
#  798: "1998 Novel &amp; Short Story Writer's Market (Novel &amp; Short Story Writer's Market, 1998)",
#  799: "1998 Poet's Market (Poet's Market, 1998)",
#  800: "1998 Writer's Market: Where &amp; How to Sell What You Write (Annual)",
#  801: '1999 (Thorndike Large Print Christian Fiction)',
#  802: "1999 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 1999)",
#  803: '1999 Entertainment Weekly Yearbook (Entertainment Weekly Yearbook)',
#  804: '1999 Guide to Literary Agents: 500 Agents Who Sell What You Write (Guide to Literary Agents)',
#  805: "1999 Novel &amp; Short Story Writer's Market (Novel and Short Story Writer's Market)",
#  806: "1999 Poet's Market (Poet's Market, 1999)",
#  807: "1999 Writer's Market (Annual)",
#  808: '19th Precinct',
#  809: '1ST AMONG EQUALS',
#  810: '1ST AMONG EQUALS X',
#  811: '1ST BORN',
#  812: '1ST MAN THEN ADAM',
#  813: '1st Corinthians (Enduring Word Commentary)',
#  814: '1st Culprit',
#  815: '1st Treasury of Herman (Andrews &amp; McMeel Treasury Series)',
#  816: '1st to Die',
#  817: '1st to Die British Edition',
#  818: '1st to Die: A Novel',
#  819: '2 Doz Red Roses',
#  820: '2 Eyes a Nose and a Mouth',
#  821: '2 FOR TEXAS',
#  822: '2 Novels:  A Fine and Private Place &amp; The Madman Theory',
#  823: '2 Of Kind',
#  824: '2 Old Women',
#  825: '2 Sweet 2 B 4-Gotten (Friends 4-Ever, No 3)',
#  826: '2 YOUNG 2 GO 4 BOYS',
#  827: '2 Years Without Sleep: Working Moms Talk About Having a Baby and a Job',
#  828: '2 minutes a day for a greener planet',
#  829: '2,000 Sports Quips and Quotes',
#  830: '2,001 Things to Do Before You Die',
#  831: '2,002 Ways To Cheer Yourself Up',
#  832: '2,100 Victorian Monograms (Dover Pictorial Archive Series)',
#  833: '2,715 One-Line Quotations',
#  834: '2-In-1: The Instant Cholesterol and Fat Control System',
#  835: '20 Holy Hours:',
#  836: '20 Hot Potatoes Christians Are Afraid To Touch',
#  837: '20 Hot Potatoes Christians Are Afraid to Touch',
#  838: '20 Jahre 40 bleiben. Jung und schÃ?Â¶n in den besten Jahren.',
#  839: '20 Master Plots (And How to Build Them)',
#  840: '20 Master Plots: And How to Build Them',
#  841: "20 Most Asked Questions About the Amish and Mennonites (People's Place Book, No 1)",
#  842: '20 Poemas De Amor Y Una Cancion Deseperada/20 Poems Desperate Song',
#  843: '20 Secrets to Money and Independence: A Guide to Independence, Economic Empowerment, and Self-Awareness',
#  844: '20 Teachable Virtues: Practical Ways to Pass on Lessons of Virtue and Character to Your Children',
#  845: '20 UNDER 30',
#  846: '20 Years of Censored News',
#  847: "20 Years of Rolling Stone: What a Long, Strange Trip It's Been",
#  848: '20 Years of the Problem Page (Vol. 2)',
#  849: "20,000 Alarms: The Memoirs of New York's Most Decorated Fireman",
#  850: '20,000 Baseball Cards Under the Sea (Step-Into-Reading, Step 4)',
#  851: '20,000 Leagues Under the Sea',
#  852: '20,000 Leagues Under the Sea (American Short Stories)',
#  853: '20,000 Leagues Under the Sea (Bantam Classics)',
#  854: '20,000 Leagues Under the Sea (Great Illustrated Classics)',
#  855: '20,000 Leagues Under the Sea (Scholastic Classics)',
#  856: '20,000 Leagues Under the Sea (Step Into Classics)',
#  857: '20,000 Leagues Under the Sea (Treasury of Illustrated Classics)',
#  858: '20,000 Leagues Under the Sea (Wordsworth Collection)',
#  859: '20,000 Leagues Under the Sea / By Jules',
#  860: "20,000 Leagues Under the Sea: The Young Collector's Illustrated Classics/Ages 8-12",
#  861: '20,000 Leagues Under the Seas',
#  862: '20,000 Leaks Under the Sea (A Golden Sight and Sound Book)',
#  863: '20,000 Men and Me',
#  864: "20,000 Secrets of Tea: The Most Effective Ways to Benefit from Nature's Healing Herbs",
#  865: '20,000 words',
#  866: '20,001 Names For Baby : Revised and Updated',
#  867: '20,001 Names for Baby',
#  868: '20-Minute Cookbook: 50 Delicious, Quick and Healthy Recipes (Step-By-Step)',
#  869: '20-Minute Crafts',
#  870: '20-Minute Retreats: Revive Your Spirit in Just Minutes a Day With Simple Self-Led Practices',
#  871: '20-Minute Yoga Workouts',
#  872: "20/20 Hindsight: From Starting Up to Successful Entrepreneur, by Those Who'Ve Been There (Virgin Business Guides)",
#  873: '20/20 Vision',
#  874: '200 Beats Per Minute',
#  875: '200 Classic Chess Puzzles',
#  876: '200 Great Painting Ideas for Artists',
#  877: '200 Small House Plans: Selected Designs Under 2,500 Square Feet (Blue Ribbon Designer Series)',
#  878: '200 Tips for Growing Beautiful Roses',
#  879: "200 Ways to Raise a Girl's Self-Esteem: An Indispensable Guide for Parents, Teachers &amp; Other Concerned Caregivers",
#  880: '200% Wife (That Special Woman!/Stanford Sisters) (Silhouette Special Edition)',
#  881: '2000 A.D.: Are You Ready? : How New Technologies and Lightning-Fast Changes Are Opening the Door for Satan and His Plan for the End of the World',
#  882: "2000 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 2000)",
#  883: '2000 INSULTS',
#  884: '2000 Kisses',
#  885: '2000 MORE INSULTS',
#  886: "2000 Photographer's Market (Photographer's Market, 2000)",
#  887: "2000 Poet's Market (Poet's Market, 2000)",
#  888: '2000 Scrapbook Hall of Fame',
#  889: '2000 Taste Of Home Annual Recipes',
#  890: "2000 Taste of Home's Quick Cooking Annual Recipes",
#  891: '2000 What Color is Your Parachute',
#  892: '2000 Year Old Man In the Year the B',
#  893: '20000 Leagues Under the Sea',
#  894: '20000 Years of Fashion',
#  895: '20000 lieues sous les mers',
#  896: '2001',
#  897: '2001 - A Space Odyssey',
#  898: "2001 - L'odyssee De L'espace",
#  899: '2001 A Space Odyssey',
#  900: '2001 Cross-Stitch Designs: The Essential Reference Book',
#  901: '2001 Formula One Annual',
#  902: '2001 French and English Idioms: 2001 Idiotismes Francais Et Anglais',
#  903: '2001 Japanese and English Idioms (2001 Idioms Series)',
#  904: "2001 Lippincott's Nursing Drug Guide (Book with Mini CD-ROM for Windows &amp; Macintosh)",
#  905: "2001 Novel &amp; Short Story Writer's Market (Novel &amp; Short Story Writer's Market, 2001)",
#  906: "2001 Poet's Market (Poet's Market, 2001)",
#  907: '2001 Spanish and English Idioms, 2001 Modismos Espa~Noles E Ingleses',
#  908: '2001 Spanish and English Idioms/2001 Modismos Espanoles E Ingleses: 2001 Modismos Espanoles E Ingleses',
#  909: "2001 Writer's Market: The Internet Edition",
#  910: '2001 a Space Odyssey',
#  911: '2001. Odyssee im Weltraum.',
#  912: '2001: A Space Odssey',
#  913: '2001: A Space Odyssey',
#  914: '2001: A Space Odyssey : a Novel by Arthur C. Clarke',
#  915: '2001: On the Edge of Eternity',
#  916: '2001: Una Odisea Espacial',
#  917: '2002 American Guide to U.S. Coins : The Most Up-to-Date Coin Prices Available (American Guide to Us Coins)',
#  918: '2002 Days &amp; Nights of Sex',
#  919: '2002 ESPN Information Please Sports Almanac: The Definitive Sports Reference Book',
#  920: "2002 Novel &amp; Short Story Writers Market (Novel and Short Story Writer's Market)",
#  921: '2002 Official Rules of Major League Baseball',
#  922: "2002 Photographer's Market (Photographer's Market, 2002)",
#  923: '2002 Romantic Ideas: Special Moments You Can Share With the One You Love',
#  924: '2002 Things to Do on a Date: From Fun, Sometimes Silly, Romantic, to the Unique (2002)',
#  925: '2002 Trailer Life Directory: Campgrounds, RV Parks, and Services',
#  926: '2002 Ways To Say \\I Love You\\""',
#  927: '2002 World Press Photo (World Press Photo, 2002)',
#  928: "2002 Writer's Market Online",
#  929: "2002 Writer's Market: 8,000 Editors Who Buy What You Write",
#  930: '2003 Guide to Literary Agents: 600+ Agents Who Sell What You Write (Guide to Literary Agents, 2003)',
#  931: '2003 Handbook of United States Coins: With Premium List (Handbook of United States Coins)',
#  932: "2003 Novel &amp; Short Story Writer's Market",
#  933: "2003 Poet's Market (Poet's Market, 2003)",
#  934: "2004 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 2004)",
#  935: "2004 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 2004)",
#  936: '2004 Kirigami Fold &amp; Cut-A-Day Calendar',
#  937: "2004 Photographer's Market (Photographer's Market, 2004)",
#  938: '2006: The Chautauqua Rising',
#  939: '2007-Eleven: And Other American Comedies',
#  940: '201 French Verbs Fully Conjugated in All the Tenses, Alphabetically Arranged.',
#  941: '201 Great Ideas for Your Small Business',
#  942: '201 Portuguese Verbs Fully Conjugated in All the Tenses, Alphabetically Arranged',
#  943: '201 Ways to Deal With Difficult People (Quick-Tip Survival Guides)',
#  944: '2010 Odisea 2',
#  945: '2010: Odisea DOS',
#  946: '2010: Odyssey Two',
#  947: '2020 VISION',
#  948: '2020 Vision',
#  949: '2024',
#  950: '2024: A Graphic Novel',
#  951: '203 Home Based Businesses That Will Make',
#  952: '203 Home-Based Businesses That Will Make You Rich : The Complete Guide to Financing and Running a Fabulously Successful Home-Based Business',
#  953: '203 Ways to Be Supremely Successful in the New World of Selling',
#  954: '203 Ways to Drive a Man Wild in Bed',
#  955: '204 Rosewood Lane',
#  956: '2041: Twelve Short Stories About the Future by Top Science Fiction Writers',
#  957: '2061. Odyssee III. Roman.',
#  958: '2061: Odyssey Three',
#  959: '2095 (Time Warp Trio)',
#  960: '2095/Your Mother Was a Neanderthal Flip Book: Your Mother Was a Neanderthal (Scieszka, Jon. Time Warp Trio.)',
#  961: '20th Century Art',
#  962: '20th Century Art Museum Ludwig Cologne (Klotz)',
#  963: '20th Century Day By Day: The Ultimate Record of Our Times',
#  964: '20th Century Design',
#  965: '20th Century Icons-Gay',
#  966: '20th Century Photography Museum Ludwig Cologne (Klotz)',
#  967: '20th Century Pop Culture',
#  968: '20th-century poetry &amp; poetics',
#  969: '21 Days to a Better Quiet Time with God',
#  970: "21 Dog Years : A Cube Dweller's Tale",
#  971: '21 Dog Years : Doing Time @ Amazon.com',
#  972: '21 Great Stories',
#  973: '21 Sugar Street',
#  974: '2107 Curious Word Origins, Sayings and Expressions from White Elephants to Song Dance',
#  975: '2150 Ad',
#  976: '2150, A. D.',
#  977: '2182 Kilohertz',
#  978: '2182 kHz',
#  979: '2194 days of war: An illustrated chronology of the Second World War with 620 illustrations and 84 maps',
#  980: '21st Century Beauty Bible',
#  981: '21st Century Blues',
#  982: '21st Century Dictionary of Computer Terms (21st Century Reference)',
#  983: '21st Century Dictionary of Quotations (21st Century Reference)',
#  984: "21st Century Etiquette: Charlotte Ford's Guide to Manners for the Modern Age",
#  985: '21st Century German-English English-German Dictionary (21st Century Reference)',
#  986: '21st Century Guide to Improving Your Writing (21st Century Reference)',
#  987: '21st Century Guide to Increasing Your Reading Speed (21st Century Reference)',
#  988: '21st Century Manual of Style',
#  989: "21st Century Robert's Rules of Order (21st Century Reference)",
#  990: "21st Century Wicca: A Young Witch's Guide to Living the Magical Life (Citadel Library of the Mystic Arts)",
#  991: '22 Days in Great Britain: The Itinerary Planner',
#  992: '22 Indigo Place',
#  993: '22 days in Norway, Sweden &amp; Denmark: The itinerary planner (JMP travel)',
#  994: '2201 Fascinating Facts',
#  995: '23 Shades of Black (Filomena Buscarsela Mysteries (Paperback))',
#  996: '2367. Experiment Hex. ( Ab 14 J.).',
#  997: '237 Intimate Questions Every Woman Should Ask a Man',
#  998: '24 Days: How Two Wall Street Journal Reporters Uncovered the Lies that Destroyed Faith in Corporate America',
#  999: "24 Essential Lessons for Investment Success: Learn the Most Important Investment Techniques from the Founder of Investor's Business Daily",
#  ...}

# %%
# Example: get 10 most similar users to user_index 0 
target_user_index = 0
target_user_id = user_id_mapping[target_user_index]

similar_users_books = rating_up[rating_up['User-ID'].isin(similar_users)] 
target_user_books = set(rating_up[rating_up['User-ID'] == target_user_id]['Book-Title'])

# %%
# Step 6: Recommend books that similar users liked (say rating ≥ 8) 
recommended_books = ( similar_users_books[
                     similar_users_books['Book-Rating'] >= 5]
                     .loc[~similar_users_books['Book-Title'].isin(target_user_books)]
                     .groupby('Book-Title')['Book-Rating']
                     .mean().sort_values(ascending=False).head(10)) 
print(f"Top recommendations for User {target_user_id}:") 
print(recommended_books)
# Out:
# Top recommendations for User 2:
# Book-Title
# Wringer (Trophy Newbery)                                   10.0
# She Said Yes : The Unlikely Martyrdom of Cassie Bernall     9.0
# The Summerhouse                                             6.0
# Name: Book-Rating, dtype: float64

# %%
book_user_matrix = csr_matrix( (rating_up['Book-Rating'], (rating_up['book_index'], rating_up['user_index'])) ) 
print(book_user_matrix.shape)
# Out:
# (241071, 92106)

# %%
book_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=6, n_jobs=-1) 
book_knn.fit(book_user_matrix) 

# Example: get similar books to the first book (index 0) 
distances, indices = book_knn.kneighbors(book_user_matrix[0], n_neighbors=6) 
print(indices) 
print(distances)
# Out:
# [[     0 239812 239807 231273 233964 211442]]
# [[0. 0. 0. 0. 0. 0.]]

# %%
# This mapping is created to link the internal index of the user book matrix to book title
book_mapping = dict( zip(rating_up['book_index'], rating_up['Book-Title']) ) 
book_id = 0 # example book index 

similar_books = indices[0][1:] 
# exclude itself 

print("Target Book:", book_mapping[book_id]) 
print("Similar Books:") 
for idx in similar_books: 
    print("-", book_mapping[idx])
# Out:
# Target Book:  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)
# Similar Books:
# - Young Indiana Jones and the Princess of Peril
# - Young Indiana Jones &amp; the Gypsy Revenge
# - Wendy and the Bullies
# - Whitney Cousins: Heather (Whitney Cousins)
# - The Ugly Duckling (Fairy Tale Classics Storybook)

# %%
# This mapping is created to link the user id to internal index of the user book matrix 
user_index_mapping = {v: k for k, v in user_id_mapping.items()}
# This mapping is created to link the book title to internal index of the user book matrix
book_index_mapping = {v: k for k, v in book_mapping.items()}

# %%
# In the KNN model, user–user similarity uses the user–book matrix (users as rows) to find users with similar rating patterns, 
# while book–book similarity uses the transposed matrix (books as rows) to find books rated similarly by users.

# %%
def hybrid_recommend(target_user_id, rating_df, top_n=10):
    # --- Step A: Find target user index ---
    if target_user_id not in user_index_mapping:
        print("User not found.")
        return
    
    target_user_index = user_index_mapping[target_user_id]

    # --- Step B: Find similar users ---
    distances, indices = user_knn.kneighbors(user_book_matrix[target_user_index], n_neighbors=6)
    similar_users = [user_id_mapping[i] for i in indices.flatten() if i != target_user_index]
    print(f"\n👥 Similar Users to {target_user_id}: {similar_users}")

    # --- Step C: Books read and rated by target user ---
    target_user_data = rating_df[rating_df['User-ID'] == target_user_id][['Book-Title', 'Book-Rating']]
    target_user_books = set(target_user_data['Book-Title'])

    print(f"\n📖 Books read by User {target_user_id}:")
    if target_user_data.empty:
        print("This user has not rated any books yet.")
    else:
        for _, row in target_user_data.iterrows():
            print(f"- {row['Book-Title']} (Rating: {row['Book-Rating']})")

    # --- Step D: Books liked by similar users (User–User based CF) ---
    similar_users_books = rating_df[rating_df['User-ID'].isin(similar_users)]
    recommended_books_user = (
        similar_users_books[similar_users_books['Book-Rating'] >= 5]
        .loc[~similar_users_books['Book-Title'].isin(target_user_books)]
        .groupby('Book-Title')['Book-Rating']
        .mean()
        .sort_values(ascending=False)
        .head(top_n)
    )

    print("\n📘 Top recommendations from similar users (User–User CF):")
    if recommended_books_user.empty:
        print("No new books found from similar users.")
    else:
        for book, rating in recommended_books_user.items():
            print(f"- {book}")

    # --- Step E: Books similar to what target user read (Item–Item based CF) ---
    similar_books_set = set()
    for book in target_user_books:
        if book in book_index_mapping:
            book_id = book_index_mapping[book]
            distances, indices = book_knn.kneighbors(book_user_matrix[book_id], n_neighbors=4)
            for idx in indices.flatten()[1:]:
                similar_books_set.add(book_mapping[idx])

    print("\n📙 Books similar to what the user has read (Item–Item CF):")
    if not similar_books_set:
        print("No similar books found.")
    else:
        similar_books_ratings = (
            rating_df[rating_df['Book-Title'].isin(similar_books_set)]
            .groupby('Book-Title')['Book-Rating']
            .mean()
            .sort_values(ascending=False)
        )

        for book, avg_rating in similar_books_ratings.head(top_n).items():
            print(f"- {book}")

    # --- Step F: Combine both sources ---
    final_recommendations = set(recommended_books_user.index).union(similar_books_set)

    print(f"\n📚 Final Combined Recommendations for User {target_user_id}:")
    if not final_recommendations:
        print("No recommendations available.")
    else:
        for book in list(final_recommendations)[:top_n]:
            print("-", book)

# %%
hybrid_recommend(target_user_id=10, rating_df=rating_up, top_n=10)
# Out:
# 👥 Similar Users to 10: [278815, 278818, 278819, 278820, 278824, 278825]
#
# 📖 Books read by User 10:
# - New Vegetarian: Bold and Beautiful Recipes for Every Occasion (Rating: 0)
#
# 📘 Top recommendations from similar users (User–User CF):
# - Wringer (Trophy Newbery)
# - She Said Yes : The Unlikely Martyrdom of Cassie Bernall
# - The Summerhouse
# - The Sweetheart Season: A Novel
#
# 📙 Books similar to what the user has read (Item–Item CF):
# - El caso de los anÃ³nimos
# - El amuleto maya (ColecciÃ³n TÃ­voli)
# - El clavo
#
# 📚 Final Combined Recommendations for User 10:
# - El amuleto maya (ColecciÃ³n TÃ­voli)
# - The Sweetheart Season: A Novel
# - The Summerhouse
# - El caso de los anÃ³nimos
# - Wringer (Trophy Newbery)
# - El clavo
# - She Said Yes : The Unlikely Martyrdom of Cassie Bernall

# %%
# Save models
joblib.dump(book_knn, 'models/book_knn.joblib')
joblib.dump(user_knn, 'models/user_knn.joblib')

# Save matrices
joblib.dump(user_book_matrix, "models/user_book_matrix.joblib")
joblib.dump(book_user_matrix, "models/book_user_matrix.joblib")

# Save mappings
joblib.dump(user_index_mapping, 'models/user_index_mapping.joblib')
joblib.dump(user_id_mapping, 'models/user_id_mapping.joblib')
joblib.dump(book_index_mapping, 'models/book_index_mapping.joblib')
joblib.dump(book_mapping, 'models/book_mapping.joblib')
# Out:
# ['models/book_mapping.joblib']
